# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/TS/Exp2/cdata2.csv")
df['DATE'] = pd.to_datetime(df['DATE'])
df.set_index('DATE', inplace=True)

plt.figure(figsize =(20,5))
plt.plot(df.index,df['Value'],marker='o',linestyle='-',color='b')
plt.title("Time Series Line Plot")
plt.xlabel("Date")
plt.ylabel("Value")
plt.legend()
plt.show()
# Out:
# <ipython-input-1-c668a59fcd1a>:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
monthly_data = df['Value'].resample('M').mean()
plt.figure(figsize =(20,6))
plt.plot(monthly_data,label ='Monthly Average')
plt.title("Monthly Trends")
plt.xlabel("Date")
plt.ylabel("Average Value")
plt.legend()
plt.show()
# Out:
# <ipython-input-2-6428b6d5d46a>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_data = df['Value'].resample('M').mean()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Value'], bins=20, kde=True, color='purple')
plt.title("Histogram of Values")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# <ipython-input-3-d4f5d4da51da>:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(6, 5))
sns.boxplot(y=df['Value'], color='orange')
plt.title("Box Plot of Values")
plt.ylabel("Value")
plt.legend()
plt.show()
# Out:
# <ipython-input-4-5bf68e45af27>:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
